# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.90  
LEARNING_RATE = 0.0025 
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.02  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
# Gamma: 0.99 - Default
# Learning Rate: 0.001 - Default
# Exploration: 0.01 - Default
cartpole()
# Out:
# Run: 1, exploration: 0.995, score: 21
# Scores: (min: 21, avg: 21, max: 21)
#
# Run: 2, exploration: 0.9000874278732445, score: 21
# Scores: (min: 21, avg: 21, max: 21)
#
# Run: 3, exploration: 0.7901049725470279, score: 27
# Scores: (min: 21, avg: 23, max: 27)
#
# Run: 4, exploration: 0.7514768435208588, score: 11
# Scores: (min: 11, avg: 20, max: 27)
#
# Run: 5, exploration: 0.6465587967553006, score: 31
# Scores: (min: 11, avg: 22.2, max: 31)
#
# Run: 6, exploration: 0.567555222460375, score: 27
# Scores: (min: 11, avg: 23, max: 31)
#
# Run: 7, exploration: 0.531750826943791, score: 14
# Scores: (min: 11, avg: 21.714285714285715, max: 31)
#
# Run: 8, exploration: 0.4907693883854626, score: 17
# Scores: (min: 11, avg: 21.125, max: 31)
#
# Run: 9, exploration: 0.46677573701590436, score: 11
# Scores: (min: 11, avg: 20, max: 31)
#
# Run: 10, exploration: 0.4439551321314536, score: 11
# Scores: (min: 11, avg: 19.1, max: 31)
#
# Run: 11, exploration: 0.40974000909221303, score: 17
# Scores: (min: 11, avg: 18.90909090909091, max: 31)
#
# Run: 12, exploration: 0.3706551064126331, score: 21
# Scores: (min: 11, avg: 19.083333333333332, max: 31)
#
# Run: 13, exploration: 0.3386767948568688, score: 19
# Scores: (min: 11, avg: 19.076923076923077, max: 31)
#
# Run: 14, exploration: 0.30483872516307353, score: 22
# Scores: (min: 11, avg: 19.285714285714285, max: 31)
#
# Run: 15, exploration: 0.27714603575484437, score: 20
# Scores: (min: 11, avg: 19.333333333333332, max: 31)
#
# Run: 16, exploration: 0.2494556624678441, score: 22
# Scores: (min: 11, avg: 19.5, max: 31)
#
# Run: 17, exploration: 0.2178795886667409, score: 28
# Scores: (min: 11, avg: 20, max: 31)
#
# Run: 18, exploration: 0.2000824143909432, score: 18
# Scores: (min: 11, avg: 19.88888888888889, max: 31)
#
# Run: 19, exploration: 0.18559023879528855, score: 16
# Scores: (min: 11, avg: 19.68421052631579, max: 31)
#
# Run: 20, exploration: 0.16373146555890544, score: 26
# Scores: (min: 11, avg: 20, max: 31)
#
# Run: 21, exploration: 0.1549480222912372, score: 12
# Scores: (min: 11, avg: 19.61904761904762, max: 31)
#
# Run: 22, exploration: 0.13946676683816583, score: 22
# Scores: (min: 11, avg: 19.727272727272727, max: 31)
#
# Run: 23, exploration: 0.12304040492325048, score: 26
# Scores: (min: 11, avg: 20, max: 31)
#
# Run: 24, exploration: 0.10119240105273684, score: 40
# Scores: (min: 11, avg: 20.833333333333332, max: 40)
#
# Run: 25, exploration: 0.09246201511725258, score: 19
# Scores: (min: 11, avg: 20.76, max: 40)
#
# Run: 26, exploration: 0.06445033334388098, score: 73
# Scores: (min: 11, avg: 22.76923076923077, max: 73)
#
# Run: 27, exploration: 0.056575091797066025, score: 27
# Scores: (min: 11, avg: 22.925925925925927, max: 73)
#
# Run: 28, exploration: 0.05380914294022049, score: 11
# Scores: (min: 11, avg: 22.5, max: 73)
#
# Run: 29, exploration: 0.051178420962124486, score: 11
# Scores: (min: 11, avg: 22.103448275862068, max: 73)
#
# Run: 30, exploration: 0.048190768399801194, score: 13
# Scores: (min: 11, avg: 21.8, max: 73)
#
# Run: 31, exploration: 0.04447676004441063, score: 17
# Scores: (min: 11, avg: 21.64516129032258, max: 73)
#
# Run: 32, exploration: 0.04230229704853423, score: 11
# Scores: (min: 11, avg: 21.3125, max: 73)
#
# Run: 33, exploration: 0.03826710124979409, score: 21
# Scores: (min: 11, avg: 21.303030303030305, max: 73)
#
# Run: 34, exploration: 0.03163025067641567, score: 39
# Scores: (min: 11, avg: 21.823529411764707, max: 73)
#
# Run: 35, exploration: 0.0279048474362789, score: 26
# Scores: (min: 11, avg: 21.942857142857143, max: 73)
#
# Run: 36, exploration: 0.021610099696926857, score: 52
# Scores: (min: 11, avg: 22.77777777777778, max: 73)
#
# Run: 37, exploration: 0.017595559502304726, score: 42
# Scores: (min: 11, avg: 23.2972972972973, max: 73)
#
# Run: 38, exploration: 0.014183896485845416, score: 44
# Scores: (min: 11, avg: 23.842105263157894, max: 73)
#
# Run: 39, exploration: 0.01184203826198843, score: 37
# Scores: (min: 11, avg: 24.17948717948718, max: 73)
#
# Run: 40, exploration: 0.01, score: 64
# Scores: (min: 11, avg: 25.175, max: 73)
#
# Run: 41, exploration: 0.01, score: 37
# Scores: (min: 11, avg: 25.463414634146343, max: 73)
#
# Run: 42, exploration: 0.01, score: 177
# Scores: (min: 11, avg: 29.071428571428573, max: 177)
#
# Run: 43, exploration: 0.01, score: 82
# Scores: (min: 11, avg: 30.302325581395348, max: 177)
#
# Run: 44, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 32.70454545454545, max: 177)
#
# Run: 45, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 34.022222222222226, max: 177)
#
# Run: 46, exploration: 0.01, score: 108
# Scores: (min: 11, avg: 35.630434782608695, max: 177)
#
# Run: 47, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 37.829787234042556, max: 177)
#
# Run: 48, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 40.270833333333336, max: 177)
#
# Run: 49, exploration: 0.01, score: 222
# Scores: (min: 11, avg: 43.97959183673469, max: 222)
#
# Run: 50, exploration: 0.01, score: 211
# Scores: (min: 11, avg: 47.32, max: 222)
#
# Run: 51, exploration: 0.01, score: 216
# Scores: (min: 11, avg: 50.627450980392155, max: 222)
#
# Run: 52, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 52.75, max: 222)
#
# Run: 53, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 54.905660377358494, max: 222)
#
# Run: 54, exploration: 0.01, score: 223
# Scores: (min: 11, avg: 58.01851851851852, max: 223)
#
# Run: 55, exploration: 0.01, score: 166
# Scores: (min: 11, avg: 59.981818181818184, max: 223)
#
# Run: 56, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 61.767857142857146, max: 223)
#
# Run: 57, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 63.3859649122807, max: 223)
#
# Run: 58, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 65.13793103448276, max: 223)
#
# Run: 59, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 66.50847457627118, max: 223)
#
# Run: 60, exploration: 0.01, score: 157
# Scores: (min: 11, avg: 68.01666666666667, max: 223)
#
# Run: 61, exploration: 0.01, score: 158
# Scores: (min: 11, avg: 69.49180327868852, max: 223)
#
# Run: 62, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 70.69354838709677, max: 223)
#
# Run: 63, exploration: 0.01, score: 138
# Scores: (min: 11, avg: 71.76190476190476, max: 223)
#
# Run: 64, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 73.140625, max: 223)
#
# Run: 65, exploration: 0.01, score: 195
# Scores: (min: 11, avg: 75.01538461538462, max: 223)
#
# Run: 66, exploration: 0.01, score: 219
# Scores: (min: 11, avg: 77.1969696969697, max: 223)
#
# Run: 67, exploration: 0.01, score: 172
# Scores: (min: 11, avg: 78.61194029850746, max: 223)
#
# Run: 68, exploration: 0.01, score: 288
# Scores: (min: 11, avg: 81.69117647058823, max: 288)
#
# Run: 69, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 82.81159420289855, max: 288)
#
# Run: 70, exploration: 0.01, score: 190
# Scores: (min: 11, avg: 84.34285714285714, max: 288)
#
# Run: 71, exploration: 0.01, score: 213
# Scores: (min: 11, avg: 86.15492957746478, max: 288)
#
# Run: 72, exploration: 0.01, score: 186
# Scores: (min: 11, avg: 87.54166666666667, max: 288)
#
# Run: 73, exploration: 0.01, score: 237
# Scores: (min: 11, avg: 89.58904109589041, max: 288)
#
# Run: 74, exploration: 0.01, score: 142
# Scores: (min: 11, avg: 90.29729729729729, max: 288)
#
# Run: 75, exploration: 0.01, score: 242
# Scores: (min: 11, avg: 92.32, max: 288)
#
# Run: 76, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 93.34210526315789, max: 288)
#
# Run: 77, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 94.15584415584415, max: 288)
#
# Run: 78, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 95, max: 288)
#
# Run: 79, exploration: 0.01, score: 211
# Scores: (min: 11, avg: 96.46835443037975, max: 288)
#
# Run: 80, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 97.25, max: 288)
#
# Run: 81, exploration: 0.01, score: 237
# Scores: (min: 11, avg: 98.9753086419753, max: 288)
#
# Run: 82, exploration: 0.01, score: 200
# Scores: (min: 11, avg: 100.20731707317073, max: 288)
#
# Run: 83, exploration: 0.01, score: 260
# Scores: (min: 11, avg: 102.13253012048193, max: 288)
#
# Run: 84, exploration: 0.01, score: 482
# Scores: (min: 11, avg: 106.6547619047619, max: 482)
#
# Run: 85, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 111.28235294117647, max: 500)
#
# Run: 86, exploration: 0.01, score: 395
# Scores: (min: 11, avg: 114.5813953488372, max: 500)
#
# Run: 87, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 119.01149425287356, max: 500)
#
# Run: 88, exploration: 0.01, score: 214
# Scores: (min: 11, avg: 120.0909090909091, max: 500)
#
# Run: 89, exploration: 0.01, score: 364
# Scores: (min: 11, avg: 122.8314606741573, max: 500)
#
# Run: 90, exploration: 0.01, score: 378
# Scores: (min: 11, avg: 125.66666666666667, max: 500)
#
# Run: 91, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 129.78021978021977, max: 500)
#
# Run: 92, exploration: 0.01, score: 202
# Scores: (min: 11, avg: 130.56521739130434, max: 500)
#
# Run: 93, exploration: 0.01, score: 353
# Scores: (min: 11, avg: 132.95698924731184, max: 500)
#
# Run: 94, exploration: 0.01, score: 311
# Scores: (min: 11, avg: 134.85106382978722, max: 500)
#
# Run: 95, exploration: 0.01, score: 373
# Scores: (min: 11, avg: 137.3578947368421, max: 500)
#
# Run: 96, exploration: 0.01, score: 238
# Scores: (min: 11, avg: 138.40625, max: 500)
#
# Run: 97, exploration: 0.01, score: 212
# Scores: (min: 11, avg: 139.16494845360825, max: 500)
#
# Run: 98, exploration: 0.01, score: 208
# Scores: (min: 11, avg: 139.8673469387755, max: 500)
#
# Run: 99, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 143.5050505050505, max: 500)
#
# Run: 100, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 143.74, max: 500)
#
# Run: 101, exploration: 0.01, score: 164
# Scores: (min: 11, avg: 145.17, max: 500)
#
# Run: 102, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 146.39, max: 500)
#
# Run: 103, exploration: 0.01, score: 100
# Scores: (min: 11, avg: 147.12, max: 500)
#
# Run: 104, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 152.01, max: 500)
#
# Run: 105, exploration: 0.01, score: 242
# Scores: (min: 11, avg: 154.12, max: 500)
#
# Run: 106, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 158.85, max: 500)
#
# Run: 107, exploration: 0.01, score: 157
# Scores: (min: 11, avg: 160.28, max: 500)
#
# Run: 108, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 161.47, max: 500)
#
# Run: 109, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 163.1, max: 500)
#
# Run: 110, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 164.44, max: 500)
#
# Run: 111, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 169.27, max: 500)
#
# Run: 112, exploration: 0.01, score: 284
# Scores: (min: 11, avg: 171.9, max: 500)
#
# Run: 113, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 176.71, max: 500)
#
# Run: 114, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 181.49, max: 500)
#
# Run: 115, exploration: 0.01, score: 367
# Scores: (min: 11, avg: 184.96, max: 500)
#
# Run: 116, exploration: 0.01, score: 314
# Scores: (min: 11, avg: 187.88, max: 500)
#
# Run: 117, exploration: 0.01, score: 329
# Scores: (min: 11, avg: 190.89, max: 500)
#
# Run: 118, exploration: 0.01, score: 248
# Scores: (min: 11, avg: 193.19, max: 500)
#
# Run: 119, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 194.5, max: 500)
#
# Run: 120, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 199.24, max: 500)
#
# Solved in 20 runs, 120 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
# Gamma: 0.99 - Increase from 0.95
# Learning Rate: 0.01 - Increase from 0.001
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 20
# Scores: (min: 20, avg: 20, max: 20)
#
# Run: 2, exploration: 0.918316468354365, score: 18
# Scores: (min: 18, avg: 19, max: 20)
#
# Run: 3, exploration: 0.8307187014821328, score: 21
# Scores: (min: 18, avg: 19.666666666666668, max: 21)
#
# Run: 4, exploration: 0.7666961448653229, score: 17
# Scores: (min: 17, avg: 19, max: 21)
#
# Run: 5, exploration: 0.7328768546436799, score: 10
# Scores: (min: 10, avg: 17.2, max: 21)
#
# Run: 6, exploration: 0.6900935609921609, score: 13
# Scores: (min: 10, avg: 16.5, max: 21)
#
# Run: 7, exploration: 0.6465587967553006, score: 14
# Scores: (min: 10, avg: 16.142857142857142, max: 21)
#
# Run: 8, exploration: 0.567555222460375, score: 27
# Scores: (min: 10, avg: 17.5, max: 27)
#
# Run: 9, exploration: 0.531750826943791, score: 14
# Scores: (min: 10, avg: 17.11111111111111, max: 27)
#
# Run: 10, exploration: 0.5134164023722473, score: 8
# Scores: (min: 8, avg: 16.2, max: 27)
#
# Run: 11, exploration: 0.4883155414435353, score: 11
# Scores: (min: 8, avg: 15.727272727272727, max: 27)
#
# Run: 12, exploration: 0.46211964903917074, score: 12
# Scores: (min: 8, avg: 15.416666666666666, max: 27)
#
# Run: 13, exploration: 0.4286478463299511, score: 16
# Scores: (min: 8, avg: 15.461538461538462, max: 27)
#
# Run: 14, exploration: 0.40974000909221303, score: 10
# Scores: (min: 8, avg: 15.071428571428571, max: 27)
#
# Run: 15, exploration: 0.3858205374665315, score: 13
# Scores: (min: 8, avg: 14.933333333333334, max: 27)
#
# Run: 16, exploration: 0.36512303261753626, score: 12
# Scores: (min: 8, avg: 14.75, max: 27)
#
# Run: 17, exploration: 0.3352984938281715, score: 18
# Scores: (min: 8, avg: 14.941176470588236, max: 27)
#
# Run: 18, exploration: 0.3237376186352221, score: 8
# Scores: (min: 8, avg: 14.555555555555555, max: 27)
#
# Run: 19, exploration: 0.30945741577570285, score: 10
# Scores: (min: 8, avg: 14.31578947368421, max: 27)
#
# Run: 20, exploration: 0.2827589419554058, score: 19
# Scores: (min: 8, avg: 14.55, max: 27)
#
# Run: 21, exploration: 0.2702863258025825, score: 10
# Scores: (min: 8, avg: 14.333333333333334, max: 27)
#
# Run: 22, exploration: 0.2570720625972084, score: 11
# Scores: (min: 8, avg: 14.181818181818182, max: 27)
#
# Run: 23, exploration: 0.24450384299593592, score: 11
# Scores: (min: 8, avg: 14.043478260869565, max: 27)
#
# Run: 24, exploration: 0.23371867538818816, score: 10
# Scores: (min: 8, avg: 13.875, max: 27)
#
# Run: 25, exploration: 0.22340924607110255, score: 10
# Scores: (min: 8, avg: 13.72, max: 27)
#
# Run: 26, exploration: 0.21142436319205632, score: 12
# Scores: (min: 8, avg: 13.653846153846153, max: 27)
#
# Run: 27, exploration: 0.2000824143909432, score: 12
# Scores: (min: 8, avg: 13.592592592592593, max: 27)
#
# Run: 28, exploration: 0.1912566947289212, score: 10
# Scores: (min: 8, avg: 13.464285714285714, max: 27)
#
# Run: 29, exploration: 0.18190617987607657, score: 11
# Scores: (min: 8, avg: 13.379310344827585, max: 27)
#
# Run: 30, exploration: 0.17388222158237718, score: 10
# Scores: (min: 8, avg: 13.266666666666667, max: 27)
#
# Run: 31, exploration: 0.1678868750508869, score: 8
# Scores: (min: 8, avg: 13.096774193548388, max: 27)
#
# Run: 32, exploration: 0.15967890763313974, score: 11
# Scores: (min: 8, avg: 13.03125, max: 27)
#
# Run: 33, exploration: 0.1473726336968319, score: 17
# Scores: (min: 8, avg: 13.151515151515152, max: 27)
#
# Run: 34, exploration: 0.13946676683816583, score: 12
# Scores: (min: 8, avg: 13.117647058823529, max: 27)
#
# Run: 35, exploration: 0.12490462201997637, score: 23
# Scores: (min: 8, avg: 13.4, max: 27)
#
# Run: 36, exploration: 0.1135578192100607, score: 20
# Scores: (min: 8, avg: 13.583333333333334, max: 27)
#
# Run: 37, exploration: 0.10533270926593409, score: 16
# Scores: (min: 8, avg: 13.64864864864865, max: 27)
#
# Run: 38, exploration: 0.08794155926129824, score: 37
# Scores: (min: 8, avg: 14.263157894736842, max: 37)
#
# Run: 39, exploration: 0.07566352740075044, score: 31
# Scores: (min: 8, avg: 14.692307692307692, max: 37)
#
# Run: 40, exploration: 0.06742445445908266, score: 24
# Scores: (min: 8, avg: 14.925, max: 37)
#
# Run: 41, exploration: 0.056575091797066025, score: 36
# Scores: (min: 8, avg: 15.439024390243903, max: 37)
#
# Run: 42, exploration: 0.04043632488927963, score: 68
# Scores: (min: 8, avg: 16.69047619047619, max: 68)
#
# Run: 43, exploration: 0.02904658009432929, score: 67
# Scores: (min: 8, avg: 17.86046511627907, max: 68)
#
# Run: 44, exploration: 0.019160670758563442, score: 84
# Scores: (min: 8, avg: 19.363636363636363, max: 84)
#
# Run: 45, exploration: 0.013972200057807112, score: 64
# Scores: (min: 8, avg: 20.355555555555554, max: 84)
#
# Run: 46, exploration: 0.011263082556340478, score: 44
# Scores: (min: 8, avg: 20.869565217391305, max: 84)
#
# Run: 47, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 22.382978723404257, max: 92)
#
# Run: 48, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 22.708333333333332, max: 92)
#
# Run: 49, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 23.408163265306122, max: 92)
#
# Run: 50, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 23.66, max: 92)
#
# Run: 51, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 23.764705882352942, max: 92)
#
# Run: 52, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 23.78846153846154, max: 92)
#
# Run: 53, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 23.735849056603772, max: 92)
#
# Run: 54, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 23.962962962962962, max: 92)
#
# Run: 55, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 24.12727272727273, max: 92)
#
# Run: 56, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 24.267857142857142, max: 92)
#
# Run: 57, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 24.614035087719298, max: 92)
#
# Run: 58, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 26.46551724137931, max: 132)
#
# Run: 59, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 27.661016949152543, max: 132)
#
# Run: 60, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 30.083333333333332, max: 173)
#
# Run: 61, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 30.80327868852459, max: 173)
#
# Run: 62, exploration: 0.01, score: 247
# Scores: (min: 8, avg: 34.29032258064516, max: 247)
#
# Run: 63, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 37.01587301587302, max: 247)
#
# Run: 64, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 40.046875, max: 247)
#
# Run: 65, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 42.15384615384615, max: 247)
#
# Run: 66, exploration: 0.01, score: 379
# Scores: (min: 8, avg: 47.25757575757576, max: 379)
#
# Run: 67, exploration: 0.01, score: 276
# Scores: (min: 8, avg: 50.67164179104478, max: 379)
#
# Run: 68, exploration: 0.01, score: 387
# Scores: (min: 8, avg: 55.61764705882353, max: 387)
#
# Run: 69, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 57.78260869565217, max: 387)
#
# Run: 70, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 64.1, max: 500)
#
# Run: 71, exploration: 0.01, score: 366
# Scores: (min: 8, avg: 68.35211267605634, max: 500)
#
# Run: 72, exploration: 0.01, score: 298
# Scores: (min: 8, avg: 71.54166666666667, max: 500)
#
# Run: 73, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 73.67123287671232, max: 500)
#
# Run: 74, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 75.51351351351352, max: 500)
#
# Run: 75, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 77.69333333333333, max: 500)
#
# Run: 76, exploration: 0.01, score: 390
# Scores: (min: 8, avg: 81.80263157894737, max: 500)
#
# Run: 77, exploration: 0.01, score: 334
# Scores: (min: 8, avg: 85.07792207792208, max: 500)
#
# Run: 78, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 86.47435897435898, max: 500)
#
# Run: 79, exploration: 0.01, score: 325
# Scores: (min: 8, avg: 89.49367088607595, max: 500)
#
# Run: 80, exploration: 0.01, score: 416
# Scores: (min: 8, avg: 93.575, max: 500)
#
# Run: 81, exploration: 0.01, score: 291
# Scores: (min: 8, avg: 96.01234567901234, max: 500)
#
# Run: 82, exploration: 0.01, score: 248
# Scores: (min: 8, avg: 97.86585365853658, max: 500)
#
# Run: 83, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 99.20481927710843, max: 500)
#
# Run: 84, exploration: 0.01, score: 259
# Scores: (min: 8, avg: 101.10714285714286, max: 500)
#
# Run: 85, exploration: 0.01, score: 307
# Scores: (min: 8, avg: 103.52941176470588, max: 500)
#
# Run: 86, exploration: 0.01, score: 240
# Scores: (min: 8, avg: 105.11627906976744, max: 500)
#
# Run: 87, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 106.39080459770115, max: 500)
#
# Run: 88, exploration: 0.01, score: 301
# Scores: (min: 8, avg: 108.60227272727273, max: 500)
#
# Run: 89, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 109.65168539325843, max: 500)
#
# Run: 90, exploration: 0.01, score: 269
# Scores: (min: 8, avg: 111.42222222222222, max: 500)
#
# Run: 91, exploration: 0.01, score: 287
# Scores: (min: 8, avg: 113.35164835164835, max: 500)
#
# Run: 92, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 114.02173913043478, max: 500)
#
# Run: 93, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 114.80645161290323, max: 500)
#
# Run: 94, exploration: 0.01, score: 252
# Scores: (min: 8, avg: 116.26595744680851, max: 500)
#
# Run: 95, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 117.46315789473684, max: 500)
#
# Run: 96, exploration: 0.01, score: 211
# Scores: (min: 8, avg: 118.4375, max: 500)
#
# Run: 97, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 119.55670103092784, max: 500)
#
# Run: 98, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 119.63265306122449, max: 500)
#
# Run: 99, exploration: 0.01, score: 270
# Scores: (min: 8, avg: 121.15151515151516, max: 500)
#
# Run: 100, exploration: 0.01, score: 285
# Scores: (min: 8, avg: 122.79, max: 500)
#
# Run: 101, exploration: 0.01, score: 428
# Scores: (min: 8, avg: 126.87, max: 500)
#
# Run: 102, exploration: 0.01, score: 232
# Scores: (min: 8, avg: 129.01, max: 500)
#
# Run: 103, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 131.05, max: 500)
#
# Run: 104, exploration: 0.01, score: 213
# Scores: (min: 8, avg: 133.01, max: 500)
#
# Run: 105, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 133.56, max: 500)
#
# Run: 106, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 134.86, max: 500)
#
# Run: 107, exploration: 0.01, score: 263
# Scores: (min: 8, avg: 137.35, max: 500)
#
# Run: 108, exploration: 0.01, score: 410
# Scores: (min: 8, avg: 141.18, max: 500)
#
# Run: 109, exploration: 0.01, score: 411
# Scores: (min: 8, avg: 145.15, max: 500)
#
# Run: 110, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 147.03, max: 500)
#
# Run: 111, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 149.07, max: 500)
#
# Run: 112, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 151.46, max: 500)
#
# Run: 113, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 152.75, max: 500)
#
# Run: 114, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 154.36, max: 500)
#
# Run: 115, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 156.03, max: 500)
#
# Run: 116, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 157.96, max: 500)
#
# Run: 117, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 159.79, max: 500)
#
# Run: 118, exploration: 0.01, score: 257
# Scores: (min: 8, avg: 162.28, max: 500)
#
# Run: 119, exploration: 0.01, score: 213
# Scores: (min: 8, avg: 164.31, max: 500)
#
# Run: 120, exploration: 0.01, score: 332
# Scores: (min: 8, avg: 167.44, max: 500)
#
# Run: 121, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 169.79, max: 500)
#
# Run: 122, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 171, max: 500)
#
# Run: 123, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 172.57, max: 500)
#
# Run: 124, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 174.61, max: 500)
#
# Run: 125, exploration: 0.01, score: 364
# Scores: (min: 8, avg: 178.15, max: 500)
#
# Run: 126, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 180.28, max: 500)
#
# Run: 127, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 181.77, max: 500)
#
# Run: 128, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 183.27, max: 500)
#
# Run: 129, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 186.26, max: 500)
#
# Run: 130, exploration: 0.01, score: 289
# Scores: (min: 8, avg: 189.05, max: 500)
#
# Run: 131, exploration: 0.01, score: 233
# Scores: (min: 11, avg: 191.3, max: 500)
#
# Run: 132, exploration: 0.01, score: 296
# Scores: (min: 12, avg: 194.15, max: 500)
#
# Run: 133, exploration: 0.01, score: 149
# Scores: (min: 12, avg: 195.47, max: 500)
#
# Solved in 33 runs, 133 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
# Gamma: 0.90 - Decrease from 0.99
# Learning Rate: 0.001 - Return to default
# Min Exploration: 0.02 - Increase from 0.01
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 20
# Scores: (min: 20, avg: 20, max: 20)
#
# Run: 2, exploration: 0.7822236754458713, score: 50
# Scores: (min: 20, avg: 35, max: 50)
#
# Run: 3, exploration: 0.6935613678313175, score: 25
# Scores: (min: 20, avg: 31.666666666666668, max: 50)
#
# Run: 4, exploration: 0.6369088258938781, score: 18
# Scores: (min: 18, avg: 28.25, max: 50)
#
# Run: 5, exploration: 0.6088145090359074, score: 10
# Scores: (min: 10, avg: 24.6, max: 50)
#
# Run: 6, exploration: 0.5761543988830038, score: 12
# Scores: (min: 10, avg: 22.5, max: 50)
#
# Run: 7, exploration: 0.5507399854171277, score: 10
# Scores: (min: 10, avg: 20.714285714285715, max: 50)
#
# Run: 8, exploration: 0.5185893309484582, score: 13
# Scores: (min: 10, avg: 19.75, max: 50)
#
# Run: 9, exploration: 0.49571413690105054, score: 10
# Scores: (min: 10, avg: 18.666666666666668, max: 50)
#
# Run: 10, exploration: 0.4738479773082268, score: 10
# Scores: (min: 10, avg: 17.8, max: 50)
#
# Run: 11, exploration: 0.4506816115185697, score: 11
# Scores: (min: 10, avg: 17.181818181818183, max: 50)
#
# Run: 12, exploration: 0.4286478463299511, score: 11
# Scores: (min: 10, avg: 16.666666666666668, max: 50)
#
# Run: 13, exploration: 0.35253382661792404, score: 40
# Scores: (min: 10, avg: 18.46153846153846, max: 50)
#
# Run: 14, exploration: 0.2649210072611673, score: 58
# Scores: (min: 10, avg: 21.285714285714285, max: 58)
#
# Run: 15, exploration: 0.1865228530605915, score: 71
# Scores: (min: 10, avg: 24.6, max: 71)
#
# Run: 16, exploration: 0.14087196468590776, score: 57
# Scores: (min: 10, avg: 26.625, max: 71)
#
# Run: 17, exploration: 0.11879805134519765, score: 35
# Scores: (min: 10, avg: 27.11764705882353, max: 71)
#
# Run: 18, exploration: 0.04771006548501318, score: 183
# Scores: (min: 10, avg: 35.77777777777778, max: 183)
#
# Run: 19, exploration: 0.02, score: 270
# Scores: (min: 10, avg: 48.10526315789474, max: 270)
#
# Run: 20, exploration: 0.02, score: 220
# Scores: (min: 10, avg: 56.7, max: 270)
#
# Run: 21, exploration: 0.02, score: 212
# Scores: (min: 10, avg: 64.0952380952381, max: 270)
#
# Run: 22, exploration: 0.02, score: 314
# Scores: (min: 10, avg: 75.45454545454545, max: 314)
#
# Run: 23, exploration: 0.02, score: 231
# Scores: (min: 10, avg: 82.21739130434783, max: 314)
#
# Run: 24, exploration: 0.02, score: 217
# Scores: (min: 10, avg: 87.83333333333333, max: 314)
#
# Run: 25, exploration: 0.02, score: 213
# Scores: (min: 10, avg: 92.84, max: 314)
#
# Run: 26, exploration: 0.02, score: 345
# Scores: (min: 10, avg: 102.53846153846153, max: 345)
#
# Run: 27, exploration: 0.02, score: 226
# Scores: (min: 10, avg: 107.11111111111111, max: 345)
#
# Run: 28, exploration: 0.02, score: 230
# Scores: (min: 10, avg: 111.5, max: 345)
#
# Run: 29, exploration: 0.02, score: 218
# Scores: (min: 10, avg: 115.17241379310344, max: 345)
#
# Run: 30, exploration: 0.02, score: 209
# Scores: (min: 10, avg: 118.3, max: 345)
#
# Run: 31, exploration: 0.02, score: 283
# Scores: (min: 10, avg: 123.61290322580645, max: 345)
#
# Run: 32, exploration: 0.02, score: 234
# Scores: (min: 10, avg: 127.0625, max: 345)
#
# Run: 33, exploration: 0.02, score: 415
# Scores: (min: 10, avg: 135.78787878787878, max: 415)
#
# Run: 34, exploration: 0.02, score: 254
# Scores: (min: 10, avg: 139.26470588235293, max: 415)
#
# Run: 35, exploration: 0.02, score: 184
# Scores: (min: 10, avg: 140.54285714285714, max: 415)
#
# Run: 36, exploration: 0.02, score: 230
# Scores: (min: 10, avg: 143.02777777777777, max: 415)
#
# Run: 37, exploration: 0.02, score: 43
# Scores: (min: 10, avg: 140.32432432432432, max: 415)
#
# Run: 38, exploration: 0.02, score: 206
# Scores: (min: 10, avg: 142.05263157894737, max: 415)
#
# Run: 39, exploration: 0.02, score: 449
# Scores: (min: 10, avg: 149.92307692307693, max: 449)
#
# Run: 40, exploration: 0.02, score: 324
# Scores: (min: 10, avg: 154.275, max: 449)
#
# Run: 41, exploration: 0.02, score: 113
# Scores: (min: 10, avg: 153.26829268292684, max: 449)
#
# Run: 42, exploration: 0.02, score: 20
# Scores: (min: 10, avg: 150.0952380952381, max: 449)
#
# Run: 43, exploration: 0.02, score: 186
# Scores: (min: 10, avg: 150.93023255813952, max: 449)
#
# Run: 44, exploration: 0.02, score: 11
# Scores: (min: 10, avg: 147.75, max: 449)
#
# Run: 45, exploration: 0.02, score: 500
# Scores: (min: 10, avg: 155.57777777777778, max: 500)
#
# Run: 46, exploration: 0.02, score: 35
# Scores: (min: 10, avg: 152.95652173913044, max: 500)
#
# Run: 47, exploration: 0.02, score: 98
# Scores: (min: 10, avg: 151.7872340425532, max: 500)
#
# Run: 48, exploration: 0.02, score: 277
# Scores: (min: 10, avg: 154.39583333333334, max: 500)
#
# Run: 49, exploration: 0.02, score: 406
# Scores: (min: 10, avg: 159.53061224489795, max: 500)
#
# Run: 50, exploration: 0.02, score: 218
# Scores: (min: 10, avg: 160.7, max: 500)
#
# Run: 51, exploration: 0.02, score: 173
# Scores: (min: 10, avg: 160.94117647058823, max: 500)
#
# Run: 52, exploration: 0.02, score: 180
# Scores: (min: 10, avg: 161.30769230769232, max: 500)
#
# Run: 53, exploration: 0.02, score: 291
# Scores: (min: 10, avg: 163.75471698113208, max: 500)
#
# Run: 54, exploration: 0.02, score: 285
# Scores: (min: 10, avg: 166, max: 500)
#
# Run: 55, exploration: 0.02, score: 283
# Scores: (min: 10, avg: 168.12727272727273, max: 500)
#
# Run: 56, exploration: 0.02, score: 357
# Scores: (min: 10, avg: 171.5, max: 500)
#
# Run: 57, exploration: 0.02, score: 232
# Scores: (min: 10, avg: 172.56140350877192, max: 500)
#
# Run: 58, exploration: 0.02, score: 270
# Scores: (min: 10, avg: 174.24137931034483, max: 500)
#
# Run: 59, exploration: 0.02, score: 206
# Scores: (min: 10, avg: 174.77966101694915, max: 500)
#
# Run: 60, exploration: 0.02, score: 145
# Scores: (min: 10, avg: 174.28333333333333, max: 500)
#
# Run: 61, exploration: 0.02, score: 286
# Scores: (min: 10, avg: 176.11475409836066, max: 500)
#
# Run: 62, exploration: 0.02, score: 213
# Scores: (min: 10, avg: 176.70967741935485, max: 500)
#
# Run: 63, exploration: 0.02, score: 179
# Scores: (min: 10, avg: 176.74603174603175, max: 500)
#
# Run: 64, exploration: 0.02, score: 324
# Scores: (min: 10, avg: 179.046875, max: 500)
#
# Run: 65, exploration: 0.02, score: 499
# Scores: (min: 10, avg: 183.96923076923076, max: 500)
#
# Run: 66, exploration: 0.02, score: 208
# Scores: (min: 10, avg: 184.33333333333334, max: 500)
#
# Run: 67, exploration: 0.02, score: 278
# Scores: (min: 10, avg: 185.73134328358208, max: 500)
#
# Run: 68, exploration: 0.02, score: 394
# Scores: (min: 10, avg: 188.7941176470588, max: 500)
#
# Run: 69, exploration: 0.02, score: 211
# Scores: (min: 10, avg: 189.1159420289855, max: 500)
#
# Run: 70, exploration: 0.02, score: 298
# Scores: (min: 10, avg: 190.67142857142858, max: 500)
#
# Run: 71, exploration: 0.02, score: 175
# Scores: (min: 10, avg: 190.45070422535213, max: 500)
#
# Run: 72, exploration: 0.02, score: 219
# Scores: (min: 10, avg: 190.84722222222223, max: 500)
#
# Run: 73, exploration: 0.02, score: 217
# Scores: (min: 10, avg: 191.2054794520548, max: 500)
#
# Run: 74, exploration: 0.02, score: 207
# Scores: (min: 10, avg: 191.4189189189189, max: 500)
#
# Run: 75, exploration: 0.02, score: 166
# Scores: (min: 10, avg: 191.08, max: 500)
#
# Run: 76, exploration: 0.02, score: 154
# Scores: (min: 10, avg: 190.5921052631579, max: 500)
#
# Run: 77, exploration: 0.02, score: 113
# Scores: (min: 10, avg: 189.58441558441558, max: 500)
#
# Run: 78, exploration: 0.02, score: 169
# Scores: (min: 10, avg: 189.32051282051282, max: 500)
#
# Run: 79, exploration: 0.02, score: 183
# Scores: (min: 10, avg: 189.2405063291139, max: 500)
#
# Run: 80, exploration: 0.02, score: 451
# Scores: (min: 10, avg: 192.5125, max: 500)
#
# Run: 81, exploration: 0.02, score: 218
# Scores: (min: 10, avg: 192.82716049382717, max: 500)
#
# Run: 82, exploration: 0.02, score: 16
# Scores: (min: 10, avg: 190.67073170731706, max: 500)
#
# Run: 83, exploration: 0.02, score: 191
# Scores: (min: 10, avg: 190.67469879518072, max: 500)
#
# Run: 84, exploration: 0.02, score: 158
# Scores: (min: 10, avg: 190.28571428571428, max: 500)
#
# Run: 85, exploration: 0.02, score: 156
# Scores: (min: 10, avg: 189.88235294117646, max: 500)
#
# Run: 86, exploration: 0.02, score: 152
# Scores: (min: 10, avg: 189.4418604651163, max: 500)
#
# Run: 87, exploration: 0.02, score: 162
# Scores: (min: 10, avg: 189.1264367816092, max: 500)
#
# Run: 88, exploration: 0.02, score: 178
# Scores: (min: 10, avg: 189, max: 500)
#
# Run: 89, exploration: 0.02, score: 234
# Scores: (min: 10, avg: 189.5056179775281, max: 500)
#
# Run: 90, exploration: 0.02, score: 332
# Scores: (min: 10, avg: 191.0888888888889, max: 500)
#
# Run: 91, exploration: 0.02, score: 245
# Scores: (min: 10, avg: 191.6813186813187, max: 500)
#
# Run: 92, exploration: 0.02, score: 166
# Scores: (min: 10, avg: 191.40217391304347, max: 500)
#
# Run: 93, exploration: 0.02, score: 188
# Scores: (min: 10, avg: 191.36559139784947, max: 500)
#
# Run: 94, exploration: 0.02, score: 185
# Scores: (min: 10, avg: 191.29787234042553, max: 500)
#
# Run: 95, exploration: 0.02, score: 154
# Scores: (min: 10, avg: 190.90526315789472, max: 500)
#
# Run: 96, exploration: 0.02, score: 305
# Scores: (min: 10, avg: 192.09375, max: 500)
#
# Run: 97, exploration: 0.02, score: 409
# Scores: (min: 10, avg: 194.3298969072165, max: 500)
#
# Run: 98, exploration: 0.02, score: 149
# Scores: (min: 10, avg: 193.8673469387755, max: 500)
#
# Run: 99, exploration: 0.02, score: 88
# Scores: (min: 10, avg: 192.7979797979798, max: 500)
#
# Run: 100, exploration: 0.02, score: 39
# Scores: (min: 10, avg: 191.26, max: 500)
#
# Run: 101, exploration: 0.02, score: 40
# Scores: (min: 10, avg: 191.46, max: 500)
#
# Run: 102, exploration: 0.02, score: 339
# Scores: (min: 10, avg: 194.35, max: 500)
#
# Run: 103, exploration: 0.02, score: 159
# Scores: (min: 10, avg: 195.69, max: 500)
#
# Solved in 3 runs, 103 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-28570d3a38eb> in <module>
#       2 # Learning Rate: 0.001 - Return to default
#       3 # Min Exploration: 0.02 - Increase from 0.01
# ----> 4 cartpole()
#
# <ipython-input-3-250f00d247fb> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
# Gamma: 0.90 - No change from previous test
# Learning Rate: 0.0025 - Increase from 0.001
# Min Exploration: 0.02 - No change from previous test
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 17
# Scores: (min: 17, avg: 17, max: 17)
#
# Run: 2, exploration: 0.8822202429488013, score: 28
# Scores: (min: 17, avg: 22.5, max: 28)
#
# Run: 3, exploration: 0.8307187014821328, score: 13
# Scores: (min: 13, avg: 19.333333333333332, max: 28)
#
# Run: 4, exploration: 0.7666961448653229, score: 17
# Scores: (min: 13, avg: 18.75, max: 28)
#
# Run: 5, exploration: 0.6935613678313175, score: 21
# Scores: (min: 13, avg: 19.2, max: 28)
#
# Run: 6, exploration: 0.6629680834613705, score: 10
# Scores: (min: 10, avg: 17.666666666666668, max: 28)
#
# Run: 7, exploration: 0.6274028820538087, score: 12
# Scores: (min: 10, avg: 16.857142857142858, max: 28)
#
# Run: 8, exploration: 0.5937455908197752, score: 12
# Scores: (min: 10, avg: 16.25, max: 28)
#
# Run: 9, exploration: 0.5507399854171277, score: 16
# Scores: (min: 10, avg: 16.22222222222222, max: 28)
#
# Run: 10, exploration: 0.5238143793828016, score: 11
# Scores: (min: 10, avg: 15.7, max: 28)
#
# Run: 11, exploration: 0.4907693883854626, score: 14
# Scores: (min: 10, avg: 15.545454545454545, max: 28)
#
# Run: 12, exploration: 0.4529463432347434, score: 17
# Scores: (min: 10, avg: 15.666666666666666, max: 28)
#
# Run: 13, exploration: 0.4180382776616619, score: 17
# Scores: (min: 10, avg: 15.76923076923077, max: 28)
#
# Run: 14, exploration: 0.3507711574848344, score: 36
# Scores: (min: 10, avg: 17.214285714285715, max: 36)
#
# Run: 15, exploration: 0.33698341088258443, score: 9
# Scores: (min: 9, avg: 16.666666666666668, max: 36)
#
# Run: 16, exploration: 0.3253644408394192, score: 8
# Scores: (min: 8, avg: 16.125, max: 36)
#
# Run: 17, exploration: 0.29580711868545667, score: 20
# Scores: (min: 8, avg: 16.352941176470587, max: 36)
#
# Run: 18, exploration: 0.25450776877280124, score: 31
# Scores: (min: 8, avg: 17.166666666666668, max: 36)
#
# Run: 19, exploration: 0.23371867538818816, score: 18
# Scores: (min: 8, avg: 17.210526315789473, max: 36)
#
# Run: 20, exploration: 0.16873052768933355, score: 66
# Scores: (min: 8, avg: 19.65, max: 66)
#
# Run: 21, exploration: 0.06317096204211972, score: 197
# Scores: (min: 8, avg: 28.095238095238095, max: 197)
#
# Run: 22, exploration: 0.047471515157588115, score: 58
# Scores: (min: 8, avg: 29.454545454545453, max: 197)
#
# Run: 23, exploration: 0.03621424652392737, score: 55
# Scores: (min: 8, avg: 30.565217391304348, max: 197)
#
# Run: 24, exploration: 0.02437265452736848, score: 80
# Scores: (min: 8, avg: 32.625, max: 197)
#
# Run: 25, exploration: 0.02, score: 71
# Scores: (min: 8, avg: 34.16, max: 197)
#
# Run: 26, exploration: 0.02, score: 91
# Scores: (min: 8, avg: 36.34615384615385, max: 197)
#
# Run: 27, exploration: 0.02, score: 106
# Scores: (min: 8, avg: 38.925925925925924, max: 197)
#
# Run: 28, exploration: 0.02, score: 74
# Scores: (min: 8, avg: 40.17857142857143, max: 197)
#
# Run: 29, exploration: 0.02, score: 75
# Scores: (min: 8, avg: 41.37931034482759, max: 197)
#
# Run: 30, exploration: 0.02, score: 64
# Scores: (min: 8, avg: 42.13333333333333, max: 197)
#
# Run: 31, exploration: 0.02, score: 121
# Scores: (min: 8, avg: 44.67741935483871, max: 197)
#
# Run: 32, exploration: 0.02, score: 63
# Scores: (min: 8, avg: 45.25, max: 197)
#
# Run: 33, exploration: 0.02, score: 84
# Scores: (min: 8, avg: 46.42424242424242, max: 197)
#
# Run: 34, exploration: 0.02, score: 73
# Scores: (min: 8, avg: 47.205882352941174, max: 197)
#
# Run: 35, exploration: 0.02, score: 81
# Scores: (min: 8, avg: 48.17142857142857, max: 197)
#
# Run: 36, exploration: 0.02, score: 98
# Scores: (min: 8, avg: 49.55555555555556, max: 197)
#
# Run: 37, exploration: 0.02, score: 128
# Scores: (min: 8, avg: 51.67567567567568, max: 197)
#
# Run: 38, exploration: 0.02, score: 111
# Scores: (min: 8, avg: 53.23684210526316, max: 197)
#
# Run: 39, exploration: 0.02, score: 159
# Scores: (min: 8, avg: 55.94871794871795, max: 197)
#
# Run: 40, exploration: 0.02, score: 139
# Scores: (min: 8, avg: 58.025, max: 197)
#
# Run: 41, exploration: 0.02, score: 144
# Scores: (min: 8, avg: 60.1219512195122, max: 197)
#
# Run: 42, exploration: 0.02, score: 157
# Scores: (min: 8, avg: 62.42857142857143, max: 197)
#
# Run: 43, exploration: 0.02, score: 168
# Scores: (min: 8, avg: 64.88372093023256, max: 197)
#
# Run: 44, exploration: 0.02, score: 170
# Scores: (min: 8, avg: 67.27272727272727, max: 197)
#
# Run: 45, exploration: 0.02, score: 180
# Scores: (min: 8, avg: 69.77777777777777, max: 197)
#
# Run: 46, exploration: 0.02, score: 438
# Scores: (min: 8, avg: 77.78260869565217, max: 438)
#
# Run: 47, exploration: 0.02, score: 249
# Scores: (min: 8, avg: 81.42553191489361, max: 438)
#
# Run: 48, exploration: 0.02, score: 254
# Scores: (min: 8, avg: 85.02083333333333, max: 438)
#
# Run: 49, exploration: 0.02, score: 202
# Scores: (min: 8, avg: 87.40816326530613, max: 438)
#
# Run: 50, exploration: 0.02, score: 227
# Scores: (min: 8, avg: 90.2, max: 438)
#
# Run: 51, exploration: 0.02, score: 254
# Scores: (min: 8, avg: 93.41176470588235, max: 438)
#
# Run: 52, exploration: 0.02, score: 254
# Scores: (min: 8, avg: 96.5, max: 438)
#
# Run: 53, exploration: 0.02, score: 169
# Scores: (min: 8, avg: 97.86792452830188, max: 438)
#
# Run: 54, exploration: 0.02, score: 187
# Scores: (min: 8, avg: 99.51851851851852, max: 438)
#
# Run: 55, exploration: 0.02, score: 180
# Scores: (min: 8, avg: 100.98181818181818, max: 438)
#
# Run: 56, exploration: 0.02, score: 323
# Scores: (min: 8, avg: 104.94642857142857, max: 438)
#
# Run: 57, exploration: 0.02, score: 160
# Scores: (min: 8, avg: 105.91228070175438, max: 438)
#
# Run: 58, exploration: 0.02, score: 442
# Scores: (min: 8, avg: 111.70689655172414, max: 442)
#
# Run: 59, exploration: 0.02, score: 223
# Scores: (min: 8, avg: 113.59322033898304, max: 442)
#
# Run: 60, exploration: 0.02, score: 202
# Scores: (min: 8, avg: 115.06666666666666, max: 442)
#
# Run: 61, exploration: 0.02, score: 204
# Scores: (min: 8, avg: 116.52459016393442, max: 442)
#
# Run: 62, exploration: 0.02, score: 154
# Scores: (min: 8, avg: 117.12903225806451, max: 442)
#
# Run: 63, exploration: 0.02, score: 134
# Scores: (min: 8, avg: 117.39682539682539, max: 442)
#
# Run: 64, exploration: 0.02, score: 21
# Scores: (min: 8, avg: 115.890625, max: 442)
#
# Run: 65, exploration: 0.02, score: 138
# Scores: (min: 8, avg: 116.23076923076923, max: 442)
#
# Run: 66, exploration: 0.02, score: 140
# Scores: (min: 8, avg: 116.5909090909091, max: 442)
#
# Run: 67, exploration: 0.02, score: 150
# Scores: (min: 8, avg: 117.08955223880596, max: 442)
#
# Run: 68, exploration: 0.02, score: 109
# Scores: (min: 8, avg: 116.97058823529412, max: 442)
#
# Run: 69, exploration: 0.02, score: 270
# Scores: (min: 8, avg: 119.18840579710145, max: 442)
#
# Run: 70, exploration: 0.02, score: 173
# Scores: (min: 8, avg: 119.95714285714286, max: 442)
#
# Run: 71, exploration: 0.02, score: 206
# Scores: (min: 8, avg: 121.16901408450704, max: 442)
#
# Run: 72, exploration: 0.02, score: 174
# Scores: (min: 8, avg: 121.90277777777777, max: 442)
#
# Run: 73, exploration: 0.02, score: 101
# Scores: (min: 8, avg: 121.61643835616438, max: 442)
#
# Run: 74, exploration: 0.02, score: 207
# Scores: (min: 8, avg: 122.77027027027027, max: 442)
#
# Run: 75, exploration: 0.02, score: 122
# Scores: (min: 8, avg: 122.76, max: 442)
#
# Run: 76, exploration: 0.02, score: 104
# Scores: (min: 8, avg: 122.51315789473684, max: 442)
#
# Run: 77, exploration: 0.02, score: 165
# Scores: (min: 8, avg: 123.06493506493507, max: 442)
#
# Run: 78, exploration: 0.02, score: 184
# Scores: (min: 8, avg: 123.84615384615384, max: 442)
#
# Run: 79, exploration: 0.02, score: 42
# Scores: (min: 8, avg: 122.81012658227849, max: 442)
#
# Run: 80, exploration: 0.02, score: 27
# Scores: (min: 8, avg: 121.6125, max: 442)
#
# Run: 81, exploration: 0.02, score: 97
# Scores: (min: 8, avg: 121.30864197530865, max: 442)
#
# Run: 82, exploration: 0.02, score: 27
# Scores: (min: 8, avg: 120.15853658536585, max: 442)
#
# Run: 83, exploration: 0.02, score: 243
# Scores: (min: 8, avg: 121.63855421686748, max: 442)
#
# Run: 84, exploration: 0.02, score: 162
# Scores: (min: 8, avg: 122.11904761904762, max: 442)
#
# Run: 85, exploration: 0.02, score: 64
# Scores: (min: 8, avg: 121.43529411764706, max: 442)
#
# Run: 86, exploration: 0.02, score: 164
# Scores: (min: 8, avg: 121.93023255813954, max: 442)
#
# Run: 87, exploration: 0.02, score: 144
# Scores: (min: 8, avg: 122.183908045977, max: 442)
#
# Run: 88, exploration: 0.02, score: 139
# Scores: (min: 8, avg: 122.375, max: 442)
#
# Run: 89, exploration: 0.02, score: 215
# Scores: (min: 8, avg: 123.41573033707866, max: 442)
#
# Run: 90, exploration: 0.02, score: 197
# Scores: (min: 8, avg: 124.23333333333333, max: 442)
#
# Run: 91, exploration: 0.02, score: 166
# Scores: (min: 8, avg: 124.6923076923077, max: 442)
#
# Run: 92, exploration: 0.02, score: 196
# Scores: (min: 8, avg: 125.46739130434783, max: 442)
#
# Run: 93, exploration: 0.02, score: 157
# Scores: (min: 8, avg: 125.80645161290323, max: 442)
#
# Run: 94, exploration: 0.02, score: 157
# Scores: (min: 8, avg: 126.13829787234043, max: 442)
#
# Run: 95, exploration: 0.02, score: 119
# Scores: (min: 8, avg: 126.06315789473685, max: 442)
#
# Run: 96, exploration: 0.02, score: 161
# Scores: (min: 8, avg: 126.42708333333333, max: 442)
#
# Run: 97, exploration: 0.02, score: 74
# Scores: (min: 8, avg: 125.88659793814433, max: 442)
#
# Run: 98, exploration: 0.02, score: 186
# Scores: (min: 8, avg: 126.5, max: 442)
#
# Run: 99, exploration: 0.02, score: 180
# Scores: (min: 8, avg: 127.04040404040404, max: 442)
#
# Run: 100, exploration: 0.02, score: 150
# Scores: (min: 8, avg: 127.27, max: 442)
#
# Run: 101, exploration: 0.02, score: 150
# Scores: (min: 8, avg: 128.6, max: 442)
#
# Run: 102, exploration: 0.02, score: 157
# Scores: (min: 8, avg: 129.89, max: 442)
#
# Run: 103, exploration: 0.02, score: 352
# Scores: (min: 8, avg: 133.28, max: 442)
#
# Run: 104, exploration: 0.02, score: 65
# Scores: (min: 8, avg: 133.76, max: 442)
#
# Run: 105, exploration: 0.02, score: 174
# Scores: (min: 8, avg: 135.29, max: 442)
#
# Run: 106, exploration: 0.02, score: 108
# Scores: (min: 8, avg: 136.27, max: 442)
#
# Run: 107, exploration: 0.02, score: 208
# Scores: (min: 8, avg: 138.23, max: 442)
#
# Run: 108, exploration: 0.02, score: 98
# Scores: (min: 8, avg: 139.09, max: 442)
#
# Run: 109, exploration: 0.02, score: 114
# Scores: (min: 8, avg: 140.07, max: 442)
#
# Run: 110, exploration: 0.02, score: 102
# Scores: (min: 8, avg: 140.98, max: 442)
#
# Run: 111, exploration: 0.02, score: 150
# Scores: (min: 8, avg: 142.34, max: 442)
#
# Run: 112, exploration: 0.02, score: 97
# Scores: (min: 8, avg: 143.14, max: 442)
#
# Run: 113, exploration: 0.02, score: 334
# Scores: (min: 8, avg: 146.31, max: 442)
#
# Run: 114, exploration: 0.02, score: 123
# Scores: (min: 8, avg: 147.18, max: 442)
#
# Run: 115, exploration: 0.02, score: 154
# Scores: (min: 8, avg: 148.63, max: 442)
#
# Run: 116, exploration: 0.02, score: 142
# Scores: (min: 18, avg: 149.97, max: 442)
#
# Run: 117, exploration: 0.02, score: 175
# Scores: (min: 18, avg: 151.52, max: 442)
#
# Run: 118, exploration: 0.02, score: 232
# Scores: (min: 18, avg: 153.53, max: 442)
#
# Run: 119, exploration: 0.02, score: 168
# Scores: (min: 21, avg: 155.03, max: 442)
#
# Run: 120, exploration: 0.02, score: 189
# Scores: (min: 21, avg: 156.26, max: 442)
#
# Run: 121, exploration: 0.02, score: 103
# Scores: (min: 21, avg: 155.32, max: 442)
#
# Run: 122, exploration: 0.02, score: 115
# Scores: (min: 21, avg: 155.89, max: 442)
#
# Run: 123, exploration: 0.02, score: 132
# Scores: (min: 21, avg: 156.66, max: 442)
#
# Run: 124, exploration: 0.02, score: 113
# Scores: (min: 21, avg: 156.99, max: 442)
#
# Run: 125, exploration: 0.02, score: 135
# Scores: (min: 21, avg: 157.63, max: 442)
#
# Run: 126, exploration: 0.02, score: 207
# Scores: (min: 21, avg: 158.79, max: 442)
#
# Run: 127, exploration: 0.02, score: 189
# Scores: (min: 21, avg: 159.62, max: 442)
#
# Run: 128, exploration: 0.02, score: 107
# Scores: (min: 21, avg: 159.95, max: 442)
#
# Run: 129, exploration: 0.02, score: 159
# Scores: (min: 21, avg: 160.79, max: 442)
#
# Run: 130, exploration: 0.02, score: 158
# Scores: (min: 21, avg: 161.73, max: 442)
#
# Run: 131, exploration: 0.02, score: 157
# Scores: (min: 21, avg: 162.09, max: 442)
#
# Run: 132, exploration: 0.02, score: 182
# Scores: (min: 21, avg: 163.28, max: 442)
#
# Run: 133, exploration: 0.02, score: 134
# Scores: (min: 21, avg: 163.78, max: 442)
#
# Run: 134, exploration: 0.02, score: 230
# Scores: (min: 21, avg: 165.35, max: 442)
#
# Run: 135, exploration: 0.02, score: 134
# Scores: (min: 21, avg: 165.88, max: 442)
#
# Run: 136, exploration: 0.02, score: 255
# Scores: (min: 21, avg: 167.45, max: 442)
#
# Run: 137, exploration: 0.02, score: 133
# Scores: (min: 21, avg: 167.5, max: 442)
#
# Run: 138, exploration: 0.02, score: 139
# Scores: (min: 21, avg: 167.78, max: 442)
#
# Run: 139, exploration: 0.02, score: 115
# Scores: (min: 21, avg: 167.34, max: 442)
#
# Run: 140, exploration: 0.02, score: 234
# Scores: (min: 21, avg: 168.29, max: 442)
#
# Run: 141, exploration: 0.02, score: 105
# Scores: (min: 21, avg: 167.9, max: 442)
#
# Run: 142, exploration: 0.02, score: 134
# Scores: (min: 21, avg: 167.67, max: 442)
#
# Run: 143, exploration: 0.02, score: 141
# Scores: (min: 21, avg: 167.4, max: 442)
#
# Run: 144, exploration: 0.02, score: 227
# Scores: (min: 21, avg: 167.97, max: 442)
#
# Run: 145, exploration: 0.02, score: 181
# Scores: (min: 21, avg: 167.98, max: 442)
#
# Run: 146, exploration: 0.02, score: 307
# Scores: (min: 21, avg: 166.67, max: 442)
#
# Run: 147, exploration: 0.02, score: 118
# Scores: (min: 21, avg: 165.36, max: 442)
#
# Run: 148, exploration: 0.02, score: 231
# Scores: (min: 21, avg: 165.13, max: 442)
#
# Run: 149, exploration: 0.02, score: 126
# Scores: (min: 21, avg: 164.37, max: 442)
#
# Run: 150, exploration: 0.02, score: 140
# Scores: (min: 21, avg: 163.5, max: 442)
#
# Run: 151, exploration: 0.02, score: 179
# Scores: (min: 21, avg: 162.75, max: 442)
#
# Run: 152, exploration: 0.02, score: 178
# Scores: (min: 21, avg: 161.99, max: 442)
#
# Run: 153, exploration: 0.02, score: 199
# Scores: (min: 21, avg: 162.29, max: 442)
#
# Run: 154, exploration: 0.02, score: 72
# Scores: (min: 21, avg: 161.14, max: 442)
#
# Run: 155, exploration: 0.02, score: 122
# Scores: (min: 21, avg: 160.56, max: 442)
#
# Run: 156, exploration: 0.02, score: 113
# Scores: (min: 21, avg: 158.46, max: 442)
#
# Run: 157, exploration: 0.02, score: 233
# Scores: (min: 21, avg: 159.19, max: 442)
#
# Run: 158, exploration: 0.02, score: 153
# Scores: (min: 21, avg: 156.3, max: 352)
#
# Run: 159, exploration: 0.02, score: 167
# Scores: (min: 21, avg: 155.74, max: 352)
#
# Run: 160, exploration: 0.02, score: 237
# Scores: (min: 21, avg: 156.09, max: 352)
#
# Run: 161, exploration: 0.02, score: 118
# Scores: (min: 21, avg: 155.23, max: 352)
#
# Run: 162, exploration: 0.02, score: 212
# Scores: (min: 21, avg: 155.81, max: 352)
#
# Run: 163, exploration: 0.02, score: 140
# Scores: (min: 21, avg: 155.87, max: 352)
#
# Run: 164, exploration: 0.02, score: 192
# Scores: (min: 27, avg: 157.58, max: 352)
#
# Run: 165, exploration: 0.02, score: 146
# Scores: (min: 27, avg: 157.66, max: 352)
#
# Run: 166, exploration: 0.02, score: 122
# Scores: (min: 27, avg: 157.48, max: 352)
#
# Run: 167, exploration: 0.02, score: 187
# Scores: (min: 27, avg: 157.85, max: 352)
#
# Run: 168, exploration: 0.02, score: 223
# Scores: (min: 27, avg: 158.99, max: 352)
#
# Run: 169, exploration: 0.02, score: 104
# Scores: (min: 27, avg: 157.33, max: 352)
#
# Run: 170, exploration: 0.02, score: 145
# Scores: (min: 27, avg: 157.05, max: 352)
#
# Run: 171, exploration: 0.02, score: 184
# Scores: (min: 27, avg: 156.83, max: 352)
#
# Run: 172, exploration: 0.02, score: 101
# Scores: (min: 27, avg: 156.1, max: 352)
#
# Run: 173, exploration: 0.02, score: 328
# Scores: (min: 27, avg: 158.37, max: 352)
#
# Run: 174, exploration: 0.02, score: 103
# Scores: (min: 27, avg: 157.33, max: 352)
#
# Run: 175, exploration: 0.02, score: 173
# Scores: (min: 27, avg: 157.84, max: 352)
#
# Run: 176, exploration: 0.02, score: 155
# Scores: (min: 27, avg: 158.35, max: 352)
#
# Run: 177, exploration: 0.02, score: 181
# Scores: (min: 27, avg: 158.51, max: 352)
#
# Run: 178, exploration: 0.02, score: 235
# Scores: (min: 27, avg: 159.02, max: 352)
#
# Run: 179, exploration: 0.02, score: 87
# Scores: (min: 27, avg: 159.47, max: 352)
#
# Run: 180, exploration: 0.02, score: 113
# Scores: (min: 27, avg: 160.33, max: 352)
#
# Run: 181, exploration: 0.02, score: 246
# Scores: (min: 27, avg: 161.82, max: 352)
#
# Run: 182, exploration: 0.02, score: 281
# Scores: (min: 64, avg: 164.36, max: 352)
#
# Run: 183, exploration: 0.02, score: 155
# Scores: (min: 64, avg: 163.48, max: 352)
#
# Run: 184, exploration: 0.02, score: 183
# Scores: (min: 64, avg: 163.69, max: 352)
#
# Run: 185, exploration: 0.02, score: 63
# Scores: (min: 63, avg: 163.68, max: 352)
#
# Run: 186, exploration: 0.02, score: 105
# Scores: (min: 63, avg: 163.09, max: 352)
#
# Run: 187, exploration: 0.02, score: 117
# Scores: (min: 63, avg: 162.82, max: 352)
#
# Run: 188, exploration: 0.02, score: 95
# Scores: (min: 63, avg: 162.38, max: 352)
#
# Run: 189, exploration: 0.02, score: 115
# Scores: (min: 63, avg: 161.38, max: 352)
#
# Run: 190, exploration: 0.02, score: 267
# Scores: (min: 63, avg: 162.08, max: 352)
#
# Run: 191, exploration: 0.02, score: 155
# Scores: (min: 63, avg: 161.97, max: 352)
#
# Run: 192, exploration: 0.02, score: 95
# Scores: (min: 63, avg: 160.96, max: 352)
#
# Run: 193, exploration: 0.02, score: 122
# Scores: (min: 63, avg: 160.61, max: 352)
#
# Run: 194, exploration: 0.02, score: 250
# Scores: (min: 63, avg: 161.54, max: 352)
#
# Run: 195, exploration: 0.02, score: 111
# Scores: (min: 63, avg: 161.46, max: 352)
#
# Run: 196, exploration: 0.02, score: 126
# Scores: (min: 63, avg: 161.11, max: 352)
#
# Run: 197, exploration: 0.02, score: 257
# Scores: (min: 63, avg: 162.94, max: 352)
#
# Run: 198, exploration: 0.02, score: 115
# Scores: (min: 63, avg: 162.23, max: 352)
#
# Run: 199, exploration: 0.02, score: 177
# Scores: (min: 63, avg: 162.2, max: 352)
#
# Run: 200, exploration: 0.02, score: 103
# Scores: (min: 63, avg: 161.73, max: 352)
#
# Run: 201, exploration: 0.02, score: 102
# Scores: (min: 63, avg: 161.25, max: 352)
#
# Run: 202, exploration: 0.02, score: 46
# Scores: (min: 46, avg: 160.14, max: 352)
#
# Run: 203, exploration: 0.02, score: 23
# Scores: (min: 23, avg: 156.85, max: 334)
#
# Run: 204, exploration: 0.02, score: 153
# Scores: (min: 23, avg: 157.73, max: 334)
#
# Run: 205, exploration: 0.02, score: 454
# Scores: (min: 23, avg: 160.53, max: 454)
#
# Run: 206, exploration: 0.02, score: 84
# Scores: (min: 23, avg: 160.29, max: 454)
#
# Run: 207, exploration: 0.02, score: 314
# Scores: (min: 23, avg: 161.35, max: 454)
#
# Run: 208, exploration: 0.02, score: 260
# Scores: (min: 23, avg: 162.97, max: 454)
#
# Run: 209, exploration: 0.02, score: 124
# Scores: (min: 23, avg: 163.07, max: 454)
#
# Run: 210, exploration: 0.02, score: 135
# Scores: (min: 23, avg: 163.4, max: 454)
#
# Run: 211, exploration: 0.02, score: 87
# Scores: (min: 23, avg: 162.77, max: 454)
#
# Run: 212, exploration: 0.02, score: 193
# Scores: (min: 23, avg: 163.73, max: 454)
#
# Run: 213, exploration: 0.02, score: 289
# Scores: (min: 23, avg: 163.28, max: 454)
#
# Run: 214, exploration: 0.02, score: 101
# Scores: (min: 23, avg: 163.06, max: 454)
#
# Run: 215, exploration: 0.02, score: 139
# Scores: (min: 23, avg: 162.91, max: 454)
#
# Run: 216, exploration: 0.02, score: 264
# Scores: (min: 23, avg: 164.13, max: 454)
#
# Run: 217, exploration: 0.02, score: 144
# Scores: (min: 23, avg: 163.82, max: 454)
#
# Run: 218, exploration: 0.02, score: 170
# Scores: (min: 23, avg: 163.2, max: 454)
#
# Run: 219, exploration: 0.02, score: 280
# Scores: (min: 23, avg: 164.32, max: 454)
#
# Run: 220, exploration: 0.02, score: 100
# Scores: (min: 23, avg: 163.43, max: 454)
#
# Run: 221, exploration: 0.02, score: 96
# Scores: (min: 23, avg: 163.36, max: 454)
#
# Run: 222, exploration: 0.02, score: 102
# Scores: (min: 23, avg: 163.23, max: 454)
#
# Run: 223, exploration: 0.02, score: 120
# Scores: (min: 23, avg: 163.11, max: 454)
#
# Run: 224, exploration: 0.02, score: 251
# Scores: (min: 23, avg: 164.49, max: 454)
#
# Run: 225, exploration: 0.02, score: 235
# Scores: (min: 23, avg: 165.49, max: 454)
#
# Run: 226, exploration: 0.02, score: 267
# Scores: (min: 23, avg: 166.09, max: 454)
#
# Run: 227, exploration: 0.02, score: 135
# Scores: (min: 23, avg: 165.55, max: 454)
#
# Run: 228, exploration: 0.02, score: 202
# Scores: (min: 23, avg: 166.5, max: 454)
#
# Run: 229, exploration: 0.02, score: 64
# Scores: (min: 23, avg: 165.55, max: 454)
#
# Run: 230, exploration: 0.02, score: 39
# Scores: (min: 23, avg: 164.36, max: 454)
#
# Run: 231, exploration: 0.02, score: 61
# Scores: (min: 23, avg: 163.4, max: 454)
#
# Run: 232, exploration: 0.02, score: 148
# Scores: (min: 23, avg: 163.06, max: 454)
#
# Run: 233, exploration: 0.02, score: 137
# Scores: (min: 23, avg: 163.09, max: 454)
#
# Run: 234, exploration: 0.02, score: 154
# Scores: (min: 23, avg: 162.33, max: 454)
#
# Run: 235, exploration: 0.02, score: 78
# Scores: (min: 23, avg: 161.77, max: 454)
#
# Run: 236, exploration: 0.02, score: 43
# Scores: (min: 23, avg: 159.65, max: 454)
#
# Run: 237, exploration: 0.02, score: 169
# Scores: (min: 23, avg: 160.01, max: 454)
#
# Run: 238, exploration: 0.02, score: 136
# Scores: (min: 23, avg: 159.98, max: 454)
#
# Run: 239, exploration: 0.02, score: 137
# Scores: (min: 23, avg: 160.2, max: 454)
#
# Run: 240, exploration: 0.02, score: 285
# Scores: (min: 23, avg: 160.71, max: 454)
#
# Run: 241, exploration: 0.02, score: 138
# Scores: (min: 23, avg: 161.04, max: 454)
#
# Run: 242, exploration: 0.02, score: 124
# Scores: (min: 23, avg: 160.94, max: 454)
#
# Run: 243, exploration: 0.02, score: 249
# Scores: (min: 23, avg: 162.02, max: 454)
#
# Run: 244, exploration: 0.02, score: 232
# Scores: (min: 23, avg: 162.07, max: 454)
#
# Run: 245, exploration: 0.02, score: 104
# Scores: (min: 23, avg: 161.3, max: 454)
#
# Run: 246, exploration: 0.02, score: 106
# Scores: (min: 23, avg: 159.29, max: 454)
#
# Run: 247, exploration: 0.02, score: 108
# Scores: (min: 23, avg: 159.19, max: 454)
#
# Run: 248, exploration: 0.02, score: 122
# Scores: (min: 23, avg: 158.1, max: 454)
#
# Run: 249, exploration: 0.02, score: 324
# Scores: (min: 23, avg: 160.08, max: 454)
#
# Run: 250, exploration: 0.02, score: 104
# Scores: (min: 23, avg: 159.72, max: 454)
#
# Run: 251, exploration: 0.02, score: 465
# Scores: (min: 23, avg: 162.58, max: 465)
#
# Run: 252, exploration: 0.02, score: 87
# Scores: (min: 23, avg: 161.67, max: 465)
#
# Run: 253, exploration: 0.02, score: 24
# Scores: (min: 23, avg: 159.92, max: 465)
#
# Run: 254, exploration: 0.02, score: 53
# Scores: (min: 23, avg: 159.73, max: 465)
#
# Run: 255, exploration: 0.02, score: 207
# Scores: (min: 23, avg: 160.58, max: 465)
#
# Run: 256, exploration: 0.02, score: 164
# Scores: (min: 23, avg: 161.09, max: 465)
#
# Run: 257, exploration: 0.02, score: 118
# Scores: (min: 23, avg: 159.94, max: 465)
#
# Run: 258, exploration: 0.02, score: 141
# Scores: (min: 23, avg: 159.82, max: 465)
#
# Run: 259, exploration: 0.02, score: 155
# Scores: (min: 23, avg: 159.7, max: 465)
#
# Run: 260, exploration: 0.02, score: 254
# Scores: (min: 23, avg: 159.87, max: 465)
#
# Run: 261, exploration: 0.02, score: 203
# Scores: (min: 23, avg: 160.72, max: 465)
#
# Run: 262, exploration: 0.02, score: 180
# Scores: (min: 23, avg: 160.4, max: 465)
#
# Run: 263, exploration: 0.02, score: 102
# Scores: (min: 23, avg: 160.02, max: 465)
#
# Run: 264, exploration: 0.02, score: 177
# Scores: (min: 23, avg: 159.87, max: 465)
#
# Run: 265, exploration: 0.02, score: 134
# Scores: (min: 23, avg: 159.75, max: 465)
#
# Run: 266, exploration: 0.02, score: 147
# Scores: (min: 23, avg: 160, max: 465)
#
# Run: 267, exploration: 0.02, score: 118
# Scores: (min: 23, avg: 159.31, max: 465)
#
# Run: 268, exploration: 0.02, score: 251
# Scores: (min: 23, avg: 159.59, max: 465)
#
# Run: 269, exploration: 0.02, score: 72
# Scores: (min: 23, avg: 159.27, max: 465)
#
# Run: 270, exploration: 0.02, score: 66
# Scores: (min: 23, avg: 158.48, max: 465)
#
# Run: 271, exploration: 0.02, score: 93
# Scores: (min: 23, avg: 157.57, max: 465)
#
# Run: 272, exploration: 0.02, score: 43
# Scores: (min: 23, avg: 156.99, max: 465)
#
# Run: 273, exploration: 0.02, score: 49
# Scores: (min: 23, avg: 154.2, max: 465)
#
# Run: 274, exploration: 0.02, score: 145
# Scores: (min: 23, avg: 154.62, max: 465)
#
# Run: 275, exploration: 0.02, score: 169
# Scores: (min: 23, avg: 154.58, max: 465)
#
# Run: 276, exploration: 0.02, score: 78
# Scores: (min: 23, avg: 153.81, max: 465)
#
# Run: 277, exploration: 0.02, score: 116
# Scores: (min: 23, avg: 153.16, max: 465)
#
# Run: 278, exploration: 0.02, score: 216
# Scores: (min: 23, avg: 152.97, max: 465)
#
# Run: 279, exploration: 0.02, score: 134
# Scores: (min: 23, avg: 153.44, max: 465)
#
# Run: 280, exploration: 0.02, score: 146
# Scores: (min: 23, avg: 153.77, max: 465)
#
# Run: 281, exploration: 0.02, score: 92
# Scores: (min: 23, avg: 152.23, max: 465)
#
# Run: 282, exploration: 0.02, score: 160
# Scores: (min: 23, avg: 151.02, max: 465)
#
# Run: 283, exploration: 0.02, score: 97
# Scores: (min: 23, avg: 150.44, max: 465)
#
# Run: 284, exploration: 0.02, score: 167
# Scores: (min: 23, avg: 150.28, max: 465)
#
# Run: 285, exploration: 0.02, score: 149
# Scores: (min: 23, avg: 151.14, max: 465)
#
# Run: 286, exploration: 0.02, score: 72
# Scores: (min: 23, avg: 150.81, max: 465)
#
# Run: 287, exploration: 0.02, score: 136
# Scores: (min: 23, avg: 151, max: 465)
#
# Run: 288, exploration: 0.02, score: 23
# Scores: (min: 23, avg: 150.28, max: 465)
#
# Run: 289, exploration: 0.02, score: 379
# Scores: (min: 23, avg: 152.92, max: 465)
#
# Run: 290, exploration: 0.02, score: 145
# Scores: (min: 23, avg: 151.7, max: 465)
#
# Run: 291, exploration: 0.02, score: 158
# Scores: (min: 23, avg: 151.73, max: 465)
#
# Run: 292, exploration: 0.02, score: 40
# Scores: (min: 23, avg: 151.18, max: 465)
#
# Run: 293, exploration: 0.02, score: 168
# Scores: (min: 23, avg: 151.64, max: 465)
#
# Run: 294, exploration: 0.02, score: 97
# Scores: (min: 23, avg: 150.11, max: 465)
#
# Run: 295, exploration: 0.02, score: 124
# Scores: (min: 23, avg: 150.24, max: 465)
#
# Run: 296, exploration: 0.02, score: 63
# Scores: (min: 23, avg: 149.61, max: 465)
#
# Run: 297, exploration: 0.02, score: 129
# Scores: (min: 23, avg: 148.33, max: 465)
#
# Run: 298, exploration: 0.02, score: 345
# Scores: (min: 23, avg: 150.63, max: 465)
#
# Run: 299, exploration: 0.02, score: 251
# Scores: (min: 23, avg: 151.37, max: 465)
#
# Run: 300, exploration: 0.02, score: 103
# Scores: (min: 23, avg: 151.37, max: 465)
#
# Run: 301, exploration: 0.02, score: 98
# Scores: (min: 23, avg: 151.33, max: 465)
#
# Run: 302, exploration: 0.02, score: 111
# Scores: (min: 23, avg: 151.98, max: 465)
#
# Run: 303, exploration: 0.02, score: 94
# Scores: (min: 23, avg: 152.69, max: 465)
#
# Run: 304, exploration: 0.02, score: 92
# Scores: (min: 23, avg: 152.08, max: 465)
#
# Run: 305, exploration: 0.02, score: 238
# Scores: (min: 23, avg: 149.92, max: 465)
#
# Run: 306, exploration: 0.02, score: 237
# Scores: (min: 23, avg: 151.45, max: 465)
#
# Run: 307, exploration: 0.02, score: 215
# Scores: (min: 23, avg: 150.46, max: 465)
#
# Run: 308, exploration: 0.02, score: 127
# Scores: (min: 23, avg: 149.13, max: 465)
#
# Run: 309, exploration: 0.02, score: 105
# Scores: (min: 23, avg: 148.94, max: 465)
#
# Run: 310, exploration: 0.02, score: 112
# Scores: (min: 23, avg: 148.71, max: 465)
#
# Run: 311, exploration: 0.02, score: 264
# Scores: (min: 23, avg: 150.48, max: 465)
#
# Run: 312, exploration: 0.02, score: 118
# Scores: (min: 23, avg: 149.73, max: 465)
#
# Run: 313, exploration: 0.02, score: 57
# Scores: (min: 23, avg: 147.41, max: 465)
#
# Run: 314, exploration: 0.02, score: 145
# Scores: (min: 23, avg: 147.85, max: 465)
#
# Run: 315, exploration: 0.02, score: 244
# Scores: (min: 23, avg: 148.9, max: 465)
#
# Run: 316, exploration: 0.02, score: 105
# Scores: (min: 23, avg: 147.31, max: 465)
#
# Run: 317, exploration: 0.02, score: 122
# Scores: (min: 23, avg: 147.09, max: 465)
#
# Run: 318, exploration: 0.02, score: 110
# Scores: (min: 23, avg: 146.49, max: 465)
#
# Run: 319, exploration: 0.02, score: 149
# Scores: (min: 23, avg: 145.18, max: 465)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-b9e10aa88d2f> in <module>
#       2 # Learning Rate: 0.0025 - Increase from 0.001
#       3 # Min Exploration: 0.02 - No change from previous test
# ----> 4 cartpole()
#
# <ipython-input-3-250f00d247fb> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#      89
#
# <ipython-input-3-250f00d247fb> in experience_replay(self)
#      56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
# ---> 58             self.model.fit(state, q_values, verbose=0)
#      59         self.exploration_rate *= EXPLORATION_DECAY
#      60         self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %% [markdown]
# ### **Explain how reinforcement learning concepts apply to the cartpole problem.**
#   * **What is the goal of the agent in this case?**
#     The goal of the agent in the cartpole is to balance the pole that sits atop a cart.  The technical goal is to choose the optimal policy to maximize the reward.  A reward could be essentially performing an action that prolongs the pole moving toward being balanced.
#   * **What are the various state values?**
#     There are 4 pieces of state:
#     1.  Cart velocity
#     2.  Cart position
#     3.  Pole angle
#     4.  Pole velocity (the velocity of the tip)
#   * **What are the possible actions that can be performed?**
#     The actions that can be performed by the agent are pushing the cart left or right which is a 0 for left and 1 for right.
#   * **What reinforcement algorithm is used for this problem?**
#     The reinforcement algorithm used in this problem is the DQN algorithm or Deep Q Network.
#
# ### **Analyze how experience replay is applied to the cartpole problem.**
#   * **How does experience replay work in this algorithm?**
#     Experience replay stores the agent's experiences in memory.  Batches of experiences are then randomly sampled from memory and used to train the model.
#   * **What is the effect of introducing a discount factor for calculating the future rewards?**
#     The effect of the discount factor is to make future rewards worth less than the current reward. The ultimate goal is to decrease the gap between the prediction and the target value.  By discounting future rewards this will bring those two values closer together.
#
# ### **Analyze how neural networks are used in deep Q-learning.**
#   * **Explain the neural network architecture that is used in the cartpole problem.**
#     The architecture used in the cartpole problem is we use 3 dense layers and the Adam optimizer.  It approximates the output based on the input it is fed.  It will predict the reward value from a particular state.  The NN in the cartpole problem learns very differently from that of a standard neural network.  It uses state and past experiences along with rewards to calculate
#   * **How does the neural network make the Q-learning algorithm more efficient?**
#     What makes Q-learning algorithms efficient is through experience replay.  It uses small batches of past experiences to make future actions.  The use of a reward system also increases performance by rewarding the agent for good decisions which in our case is increasing the amount of time the pole is still in play.
#   * **What difference do you see in the algorithm performance when you increase or decrease the learning rate?**
#     The most notable difference I noticed is that whenever I changed the learning rate from 0.001 to 0.0025 it did not find a solution after 300+ runs, another thing that was make clear was whenever the score for a run was lower than the previous score the impact to the avg was note has evident as it was in previous tests.  It also took considerably longer to reach a solution when the learning rate was increased.
